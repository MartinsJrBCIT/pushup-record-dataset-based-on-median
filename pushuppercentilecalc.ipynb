# %%
#installation code
# !mamba install pandas
# !mamba install opendatasets
# !mamba install legacy-cgi

#real code


import pandas
import time

data = pandas.read_csv('male_pushup_records_ages_13_to_70.csv')

meanPushup = data['Max Pushups'].mean()
print(f"Mean of Pushup data: {meanPushup}")
time.sleep(2)
age = float(input("List your age here:"))

pushupsMax = float(input("List how many pushups can you do:"))

pushupData = sorted(data['Max Pushups'])
pushupData.append(pushupsMax)
pushupCalc = []

sortedPushupData = sorted(pushupData)

for pushups in sortedPushupData:

    if pushups > pushupsMax:
        break
    else:
        pushupCalc.append(pushups)

percentile = (len(pushupCalc)/len(sortedPushupData))*100
print(f"Overall Percentile: {round(percentile,2)}%")

ageData = data[data['Age'] == age]
if len(ageData) == 0:
    time.sleep(2)
    print("We have nobody in your age range to compare you to.")
    
else:
    pushupAgeData = sorted(ageData['Max Pushups'])
    pushupAgeData.append(pushupsMax)
    pushupAgeCalc = []

    sortedPushupAgeData = sorted(pushupAgeData)

    for pushupsinAge in sortedPushupAgeData:

        if pushupsinAge > pushupsMax:
            break
        else:
            pushupAgeCalc.append(pushupsinAge)

    agePercentile = (len(pushupAgeCalc)/len(sortedPushupAgeData))*100
    time.sleep(2)
    print(f"In your Age range you can do more pushups than {round(agePercentile,2)}% of people!")
# Out:
# mambajs 0.21.4
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 4.877 seconds
#   Name           Version  Build                Channel
# --------------------------------------------------------------------
# + pandas         3.0.6    np23py313h124dbc7_0  emscripten-forge-4x
# + python-tzdata  2026.4   pyh5ded981_0         conda-forge
# - pip            26.2.1   pyh145f28c_0         conda-forge
# mambajs 0.21.4
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, opendatasets
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 2.228 seconds
#   Name                   Version    Build            Channel
# --------------------------------------------------------------------------
# + attrs                  26.1.0     pyhcf101f3_0     conda-forge
# + bleach                 6.4.0      pyhcf101f3_0     conda-forge
# + brotli-python          1.2.0      py313ha26e73d_2  emscripten-forge-4x
# + certifi                2026.7.22  pyhd8ed1ab_0     conda-forge
# + charset-normalizer     3.5.1      pyhd8ed1ab_0     conda-forge
# + click                  8.5.0      pyh5ded981_0     conda-forge
# + idna                   3.20       pyh5ded981_0     conda-forge
# + importlib_resources    7.1.0      pyhd8ed1ab_0     conda-forge
# + importlib-metadata     9.0.1      pyhcf101f3_0     conda-forge
# + jsonschema             4.17.3     pyhd8ed1ab_0     conda-forge
# + jupyter_core           5.9.1      pyhc90fa1f_0     conda-forge
# + jupytext               1.19.5     pyh0398c0e_0     conda-forge
# + kaggle                 2.2.3      pyhc364b38_0     conda-forge
# + kagglesdk              0.1.37     pyhc364b38_0     conda-forge
# + libyaml                0.2.5      h8b79025_0       emscripten-forge-4x
# + markdown-it-py         4.2.0      pyhd8ed1ab_0     conda-forge
# + mdit-py-plugins        0.6.1      pyhd8ed1ab_0     conda-forge
# + mdurl                  0.1.2      pyhd8ed1ab_1     conda-forge
# + nbformat               5.11.1     pyhcf101f3_0     conda-forge
# + opendatasets           0.1.22     pyhd8ed1ab_0     conda-forge
# + pkgutil-resolve-name   1.3.10     pyhd8ed1ab_2     conda-forge
# + platformdirs           4.11.12    pyh5ded981_0     conda-forge
# + protobuf               6.33.6     py313h6d8a2ba_0  emscripten-forge-4x
# + pyrsistent             0.20.0     py313h6d8a2ba_2  emscripten-forge-4x
# + pysocks                1.7.1      py313h1804a44_3  emscripten-forge-4x
# + python-dotenv          1.2.3      pyhcf101f3_0     conda-forge
# + python-fastjsonschema  2.22.2     pyhcf101f3_0     conda-forge
# + python-slugify         9.0.0      pyh5ded981_0     conda-forge
# + pyyaml                 6.0        py313h1804a44_3  emscripten-forge-4x
# + requests               2.34.2     pyhcf101f3_0     conda-forge
# + text-unidecode         1.3        pyhd8ed1ab_2     conda-forge
# + tomli                  2.4.1      pyhcf101f3_0     conda-forge
# + tqdm                   4.70.1     pyhfa0c392_0     conda-forge
# + urllib3                2.2.2      pyhd8ed1ab_0     conda-forge
# + webencodings           0.5.1      pyhd8ed1ab_3     conda-forge
# + zipp                   4.1.0      pyhcf101f3_0     conda-forge
# mambajs 0.21.4
#
# Specs: xeus-python, numpy, matplotlib, pillow, ipywidgets>=8.1.6, ipyleaflet, scipy, pandas, opendatasets, legacy-cgi
# Channels: emscripten-forge-4x, conda-forge
#
# Solving environment...
# Solving took 1.768 seconds
#   Name        Version  Build         Channel
# --------------------------------------------------
# + legacy-cgi  2.6.4    pyh742d864_0  conda-forge
